# %%
import pandas as pd

# %%
df = pd.read_csv('health_data.csv')

# %%
df
# Out:
#          id  poids (kg)  taille (cm)  Fréquence cardiaque par minutes  \
# 0         1  105.285055   161.591739                               75
# 1         2  114.806815   182.108463                               94
# 2         3   86.214329   178.122908                               65
# 3         4   54.454312   148.782855                               75
# 4         5   66.849552   142.359117                               62
# ...     ...         ...          ...                              ...
# 9995   9996   41.617169   178.969018                               98
# 9996   9997   78.618477   164.617319                               58
# 9997   9998   56.638382   171.865200                               61
# 9998   9999   41.264186   141.442739                               65
# 9999  10000   71.941375   146.003071                               67
#
#       Tension arterielle systolique matin  Tension arterielle systolique soir  \
# ...
