# %%
import pandas as pd

# %%
path = '/home/dakoro/Doctolib_David/csv_files/general.csv'
df = pd.read_csv(path)
df_gr = df.groupby('patient_username').first().reset_index()
df_gr.select_dtypes(exclude=[object])
# Out:
#     id  poids_kg   taille_cm  frequence_cardiaque  tension_arterielle  \
# 0   46       NaN  178.825041                   82                 127
# 1   81       NaN  159.973133                   73                  84
# 2   21       NaN  187.376650                   71                 125
# 3   36       NaN  191.081691                   74                  77
# 4   91       NaN  197.058175                   78                  88
# 5   41       NaN  190.764315                   55                 112
# 6   26       NaN  149.792965                   61                  73
# 7   71       NaN  151.939942                   67                 139
# 8   86       NaN  143.385209                   63                  72
# 9   16       NaN  179.702745                   83                  86
# 10  96       NaN  144.440255                   90                  97
# 11  11       NaN  156.423228                   90                  67
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(df_gr.select_dtypes(exclude=[object]))
plt.show()
# Out:
# /home/dakoro/Doctolib_David/doc/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/dakoro/Doctolib_David/doc/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/dakoro/Doctolib_David/doc/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
